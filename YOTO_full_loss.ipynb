# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
fw1 = [1791.0880590511274, 1776.0999554984178, 1777.4745444768591, 1794.6084494288964]
fw2 = [1724.9300258974486, 1730.2648106828522, 1742.8041945831685, 1770.117901379549]
fw4 = [1758.0605066999603, 1766.1631693779668, 1760.7211048753957, 1817.4065142281447]
yoto1 = [1812.1621866346914, 1829.2998479529272, 1835.9897893591772, 1860.1140306690072]
yoto2 = [1773.4991640501385, 1784.2135318804392, 1802.9030421776108, 1833.0603320930577]
yoto4 = [1784.5828362959849, 1802.8281883529469, 1811.5719164111947, 1843.0523326246043]

# %%
fw1 = np.asarray(fw1)
fw2 = np.asarray(fw2)
fw4 = np.asarray(fw4)
yoto1 = np.asarray(yoto1)
yoto2 = np.asarray(yoto2)
yoto4 = np.asarray(yoto4)

# %%
log2 = [0, 4, 6, 8]

# %%
plt.plot(log2, fw1-fw1, c='b')
plt.plot(log2, fw2-fw1, c='g')
plt.plot(log2, fw4-fw1, c='r')
plt.plot(log2, yoto1-fw1, c='k')
plt.plot(log2, yoto2-fw1, c='c')
plt.plot(log2, yoto4-fw1, c='m')
plt.xlabel('log2 of beta')
plt.ylabel('Full loss Difference')
plt.legend(['fw1', 'fw2', 'fw4','yoto1' ,'yoto2', 'yoto4'])
plt.savefig('full_loss_diff')
